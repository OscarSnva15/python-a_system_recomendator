# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
import seaborn as sb


dataframe = pd.read_csv('../querys/crecimientoNicolasRomero.csv')
dataframe.head(10)
# Out:
#    numero conteo       ID                          Clee  \
# 0              1  9045956  15060114119000032000000000U1
# 1              2  6170967  15060112512000031000000000U1
# 2              3  9017141  15060112512000091000000000U5
# 3              4  8806146  15060112512000062000000000U6
# 4              5  9045955  15060114119000022000000000U2
# 5              6  8835831  15060112512000041000000000U0
# 6              7  9046020  15060114119000041000000000U2
# 7              8  8203577  15060112512000081000000000U6
# 8              9  8443622  15060112512000073000000000U3
# 9             10  7863384  15060114119000012000000000U3
#
#                        Nombre_de_la_Unidad_Económica         Razón social  \
# 0  CRIANZA ENGORDA Y COMERCIALIZADORA DE TRUCHAS ...                  NaN
# 1                  DESARROLLO ECOTURISTICO 3 PIEDRAS                  NaN
# 2                                      EL POLVORIN 2                  NaN
# 3                     GRANJA DE TRUCHAS EL POLVORIN                   NaN
# 4                GRANJA DE TRUCHAS RANCHO EL PARAISO                  NaN
# 5                                    GRANJA EL TULAR     GRANJA EL TULAR
# 6                                      LA CANTERA II                  NaN
# 7                                 LOS TRES POTRILLOS  LOS TRES POTRILLOS
# 8                                    TRUCHAS CHIRANI     TRUCHAS CHIRANI
# 9                              TRUCHAS CIELITO LINDO                  NaN
#
#    Código_de_la_clase_de_actividad_SCIAN  \
# 0                                 112512
# 1                                 112512
# 2                                 112512
# 3                                 112512
# 4                                 112512
# 5                                 112512
# 6                                 112512
# 7                                 112512
# 8                                 112512
# 9                                 112512
#
#                      Nombre_de_clase_de_la_actividad  \
# 0  Piscicultura y otra acuicultura, excepto camar...
# 1  Piscicultura y otra acuicultura, excepto camar...
# 2  Piscicultura y otra acuicultura, excepto camar...
# 3  Piscicultura y otra acuicultura, excepto camar...
# 4  Piscicultura y otra acuicultura, excepto camar...
# 5  Piscicultura y otra acuicultura, excepto camar...
# 6  Piscicultura y otra acuicultura, excepto camar...
# 7  Piscicultura y otra acuicultura, excepto camar...
# 8  Piscicultura y otra acuicultura, excepto camar...
# 9  Piscicultura y otra acuicultura, excepto camar...
#
#   Descripcion estrato personal ocupado    Tipo de vialidad  \
# 0                      6 a 10 personas  OTRO (ESPECIFIQUE)
# 1                       0 a 5 personas            CALLEJON
# 2                       0 a 5 personas  OTRO (ESPECIFIQUE)
# 3                       0 a 5 personas  OTRO (ESPECIFIQUE)
# 4                      6 a 10 personas  OTRO (ESPECIFIQUE)
# 5                       0 a 5 personas  OTRO (ESPECIFIQUE)
# 6                       0 a 5 personas  OTRO (ESPECIFIQUE)
# 7                       0 a 5 personas  OTRO (ESPECIFIQUE)
# 8                      6 a 10 personas  OTRO (ESPECIFIQUE)
# 9                       0 a 5 personas               CALLE
#
#        Nombre de la vialidad  ...            Localidad  \
# 0             las manzanitas  ...          Las Espinas
# 1           PARAJE RIO HONDO  ...              Miranda
# 2                    NINGUNO  ...          Las Espinas
# 3                LAS TRUCHAS  ...  Loma de Chapultepec
# 4                    ninguno  ...              Miranda
# 5                    NINGUNO  ...          Las Espinas
# 6             planta villada  ...          Las Espinas
# 7  NICOLAS ROMERO-JILOTZINGO  ...            El Tanque
# 8  NICOLAS ROMERO-JILOTZINGO  ...            El Tanque
# 9            Francisco villa  ...  Barrio de Guadalupe
#
#   Área_geoestadística_básica Manzana Número de teléfono   Correo electrónico  \
# 0                        471     800       5.513182e+09                  NaN
# 1                        471     800       5.522769e+09                  NaN
# 2                        471     800       5.511705e+09                  NaN
# 3                        471     800       5.564033e+09                  NaN
# 4                        471     800       5.534853e+09  ADI.TEM@HOTMAIL.COM
# 5                        471     800       5.515787e+09                  NaN
# 6                        471     800                NaN                  NaN
# 7                        486     800       5.532111e+09                  NaN
# 8                        486     800                NaN                  NaN
# 9                        486       1       5.566349e+09                  NaN
#
#   Sitio en Internet  Tipo de establecimiento    Latitud   Longitud  \
# 0               NaN                     Fijo  19.616022 -99.440017
# 1               NaN                     Fijo  19.639881 -99.432803
# 2               NaN                     Fijo  19.588705 -99.422713
# 3               NaN                     Fijo  19.604402 -99.417793
# 4               NaN                     Fijo  19.638993 -99.427058
# 5               NaN                     Fijo  19.596797 -99.442496
# 6               NaN                     Fijo  19.616022 -99.440017
# 7               NaN                     Fijo  19.591583 -99.358893
# 8               NaN                     Fijo  19.591583 -99.358893
# 9               NaN                     Fijo  19.601580 -99.420113
#
#   Fecha_de_incorporacion_al_DENUE
# 0                         2019-11
# 1                         2010-07
# 2                         2019-11
# 3                         2019-11
# 4                         2019-11
# 5                         2019-11
# 6                         2019-11
# 7                         2019-11
# 8                         2019-11
# 9                         2019-11
#
# [10 rows x 43 columns]

# %%
dataframe.describe()
# Out:
#        numero conteo            ID  Código_de_la_clase_de_actividad_SCIAN  \
# count   16243.000000  1.624300e+04                           16243.000000
# mean     8122.000000  5.162829e+06                          547241.154897
# std      4689.094547  2.863400e+06                          153447.349899
# min         1.000000  2.236925e+06                          112512.000000
# 25%      4061.500000  2.414189e+06                          461110.000000
# 50%      8122.000000  2.472477e+06                          465311.000000
# 75%     12182.500000  7.914368e+06                          722511.000000
# max     16243.000000  9.387368e+06                          931810.000000
#
#        Número exterior o kilómetro  Número interior  Código Postal  \
# count                  7260.000000      4756.000000   16134.000000
# mean                     30.342287         1.732759   54440.134932
# std                     254.549506        15.328285     384.853716
# min                       0.000000         0.000000    6020.000000
# 25%                       0.000000         0.000000   54416.000000
# 50%                       3.000000         0.000000   54440.000000
# 75%                      30.000000         0.000000   54469.000000
# max                   20080.000000       404.000000   55000.000000
#
#        Clave entidad  Clave municipio  Clave localidad       Manzana  \
# count        16243.0          16243.0     16243.000000  16243.000000
# mean            15.0             60.0         5.082682     24.173921
# std              0.0              0.0        14.631196     32.370947
# min             15.0             60.0         1.000000      1.000000
# 25%             15.0             60.0         1.000000      9.000000
# 50%             15.0             60.0         1.000000     19.000000
# 75%             15.0             60.0         1.000000     32.000000
# max             15.0             60.0       100.000000    800.000000
#
#        Número de teléfono       Latitud      Longitud
# count        3.619000e+03  16243.000000  16243.000000
# mean         9.785599e+09     19.619577    -99.313725
# std          9.882082e+10      0.018664      0.031627
# min          0.000000e+00     19.573532    -99.500000
# 25%          5.523358e+09     19.605780    -99.322630
# 50%          5.542941e+09     19.619014    -99.307118
# 75%          5.561408e+09     19.629627    -99.292316
# max          5.516824e+12     19.692578    -99.267305
